# %%
print("test:")
# Out:
# test:

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
llm4=ChatGroq(model="openai/gpt-oss-120b", temperature=0)
# llm_with_tools= llm4.bind_tools([
#     {"type":"image_generation", "quality":"high"}
# ])

# %%
# print(llm_with_tools.kwargs)
# Out:
# {'tools': [{'type': 'image_generation', 'quality': 'high'}]}

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage
from IPython.display import Image
import base64

# %%
resp = llm4.invoke(input=[
    HumanMessage(content="Je veux un chat devant son setup de gaming entrain de jouer à un jeu vidéo, style cartoon, couleurs vives, très détaillé, 4k"),
    
])

# %%
print(resp.content)
# Out:
# Voici une description détaillée qui correspond à ce que vous imaginez :
#
# **Scène générale**
# Un chat anthropomorphe, debout sur ses pattes arrière, est installé devant un poste de jeu ultra‑moderne. Le décor est un mélange de chambre de gamer et de studio d’art, le tout rendu dans un style cartoon aux couleurs vives et hyper‑détaillé, comme si on le regardait en 4 K.
#
# **Le chat**
# - **Espèce & apparence** : Un chat tigré au pelage orange‑roux avec des rayures noires bien marquées. Ses yeux sont de grands ovales verts émeraude, très expressifs, avec de petites étincelles de lumière qui reflètent l’écran.
# - **Posture** : Il est assis sur une chaise de gaming ergonomique, les pattes avant posées sur le clavier, les doigts (ou plutôt les griffes) légèrement arrondis comme s’il tapait. Son corps est légèrement penché en avant, montrant son excitation.
# ...
