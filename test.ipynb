# %%
print("test:")
# Out:
# test:

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
llm=ChatGroq(model="openai/gpt-oss-120b", temperature=0.4)
llm_with_tools= llm.bind_tools([
    {"type":"image_generation", "quality":"high"}
])

# %%
res=llm_with_tools.invoke(input=[
    {"role":user, "content":"Je veux un chat devant son setup de gaming entrain de jouer à un jeu vidéo, style cartoon, couleurs vives, très détaillé, 4k"}
])
# Out:
#   Cell In[12], line 2
#     {"role":user}, "content":"Je veux un chat devant son setup de gaming entrain de jouer à un jeu vidéo, style cartoon, couleurs vives, très détaillé, 4k"
#                             ^
# SyntaxError: invalid syntax
