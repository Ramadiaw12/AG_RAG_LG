# %%
print("test: 99 pencent man are trash")
# Out:
# test: 99 pencent man are trash

# %%
from langchain_grok import ChatGrok
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain_grok import ChatGrok
#       2 from dotenv import load_dotenv
#
# ModuleNotFoundError: No module named 'langchain_grok'

# %%
load_dotenv(override=True)

# %%
llm=ChatGrot(model="openai/gpt-oss-120b", temperature=0.4)
llm_tools= llm4.bind.tools([
    {"type":"image_generation", "quality":"high"}
])

# %%
res=llm_tools.invoke(inpust[
    {"role":user}, "content":"Je veux un chat devant son setup de gaming entrain de jouer à un jeu vidéo, style cartoon, couleurs vives, très détaillé, 4k"
])
